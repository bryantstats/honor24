# %%
import pandas as pd

# Load the processed Excel file
file_path = 'NBA_Clutch_Performance_Analysis.xlsx'

# Read the combined data sheet
df = pd.read_excel(file_path, sheet_name='Combined Data')

# Define the formula for calculating performance score
def calculate_performance_score(row, prefix):
    return (
        1.2 * row[f'PTS_{prefix}'] +
        0.5 * row[f'FGM_{prefix}'] -
        0.25 * row[f'FGA_{prefix}'] -
        0.8 * (row[f'FTA_{prefix}'] - row[f'FTM_{prefix}']) +
        0.5 * row[f'OREB_{prefix}'] +
        0.2 * row[f'DREB_{prefix}'] +
        1.2 * row[f'STL_{prefix}'] +
        1.0 * row[f'AST_{prefix}'] +
        1.0 * row[f'BLK_{prefix}'] -
        0.5 * row[f'PF_{prefix}'] -
        1.0 * row[f'TOV_{prefix}']
    )

# Calculate the clutch and general performance scores
df['Performance_Score_Clutch'] = df.apply(lambda row: calculate_performance_score(row, 'Clutch'), axis=1)
df['Performance_Score_General'] = df.apply(lambda row: calculate_performance_score(row, 'General'), axis=1)

# Calculate the clutch score
df['Clutch_Score'] = df['Performance_Score_Clutch'] - df['Performance_Score_General']

# Sort players by clutch score in descending order
df_sorted = df.sort_values(by='Clutch_Score', ascending=False)

# Display the top 20 players with the highest clutch score
top_20_players = df_sorted[['Player', 'Clutch_Score']].head(20)
print(top_20_players)

# Optionally, save the top 20 players to a new Excel file
top_20_players.to_excel('Top_20_Clutch_Players.xlsx', index=False)

print("Top 20 clutch players saved to 'Top_20_Clutch_Players.xlsx'.")
# Out:
#                Player  Clutch_Score
# 288      Amari Bailey       1.12115
# 454         Ish Smith       0.70435
# 295   Jerome Robinson       0.64560
# 424           JT Thor       0.37610
# 354     Darius Bazley       0.32575
# 452     Trent Forrest       0.32360
# 460       Pat Spencer       0.28800
# 73        Jalen Smith       0.28560
# 436       Leaky Black       0.27745
# 5       Stephen Curry       0.25685
# 145      Bones Hyland       0.24600
# 387    Troy Brown Jr.       0.24250
# 37    Anfernee Simons       0.19070
# 327   Dominick Barlow       0.18930
# 62   Ricky Council IV       0.18220
# 162       Buddy Hield       0.18075
# 364        Josh Green       0.17480
# 253        Danté Exum       0.16775
# 359       Amir Coffey       0.16690
# 414       Dalen Terry       0.16530
# Top 20 clutch players saved to 'Top_20_Clutch_Players.xlsx'.

# %%
# Adding Requirements (>50GP_R, >10GP_C, >10%USG (regular and clutch)

# %%
import pandas as pd

# Load the processed Excel file
file_path = 'NBA_Clutch_Performance_Analysis.xlsx'

# Read the combined data sheet
df = pd.read_excel(file_path, sheet_name='Combined Data')

# Define the formula for calculating performance score
def calculate_performance_score(row, prefix):
    return (
        1.2 * row[f'PTS_{prefix}'] +
        0.5 * row[f'FGM_{prefix}'] -
        0.25 * row[f'FGA_{prefix}'] -
        0.8 * (row[f'FTA_{prefix}'] - row[f'FTM_{prefix}']) +
        0.5 * row[f'OREB_{prefix}'] +
        0.2 * row[f'DREB_{prefix}'] +
        1.2 * row[f'STL_{prefix}'] +
        1.0 * row[f'AST_{prefix}'] +
        1.0 * row[f'BLK_{prefix}'] -
        0.5 * row[f'PF_{prefix}'] -
        1.0 * row[f'TOV_{prefix}']
    )

# Calculate performance scores for general and clutch stats
df['Performance_Score_Clutch'] = df.apply(lambda row: calculate_performance_score(row, 'Clutch'), axis=1)
df['Performance_Score_General'] = df.apply(lambda row: calculate_performance_score(row, 'General'), axis=1)

# Calculate clutch score
df['Clutch_Score'] = df['Performance_Score_Clutch'] - df['Performance_Score_General']

# Apply filtering conditions based on correct column names
filtered_df = df[
    (df['GP_General_Trad'] >= 50) &   # At least 50 games played in general time
    (df['GP_Clutch_Trad'] >= 10) &    # At least 10 games played in clutch time
    (df['USG%_General'] > 10) &       # USG% greater than 10% in general time
    (df['USG%_Clutch'] > 10)          # USG% greater than 10% in clutch time
]

# Sort by clutch score in descending order
df_sorted = filtered_df.sort_values(by='Clutch_Score', ascending=False)

# Display the top 20 players with the highest clutch score
top_20_players = df_sorted[['Player', 'Clutch_Score', 'GP_General_Trad', 'GP_Clutch_Trad', 'USG%_General', 'USG%_Clutch']].head(20)
print(top_20_players)

# Save the top 20 players to a new Excel file
top_20_players.to_excel('Top_20_Clutch_Players_Filtered.xlsx', index=False)

print("Top 20 clutch players with filters applied saved to 'Top_20_Clutch_Players_Filtered.xlsx'.")
# Out:
#                       Player  Clutch_Score  GP_General_Trad  GP_Clutch_Trad  \
# 5              Stephen Curry       0.25685               74              43
# 162              Buddy Hield       0.18075               84              29
# 364               Josh Green       0.17480               57              17
# 253               Danté Exum       0.16775               55              14
# 359              Amir Coffey       0.16690               70              19
# 77           Jordan Clarkson       0.15210               55              19
# 41             DeMar DeRozan       0.14710               79              40
# 55         Tyrese Haliburton       0.14610               69              28
# 56              Terry Rozier       0.14280               61              29
# 34            Damian Lillard       0.13600               73              37
# 13              Kyrie Irving       0.13225               58              20
# 31                Trae Young       0.11470               54              31
# 360         Patrick Beverley       0.11350               73              14
# 207           Malaki Branham       0.10215               75              14
# 2    Shai Gilgeous-Alexander       0.09925               75              34
# 213            Dillon Brooks       0.09340               72              33
# 237           Gordon Hayward       0.09000               51              16
# 58            Jalen Williams       0.08160               71              32
# 20         Jaren Jackson Jr.       0.07780               66              30
# 67             Mikal Bridges       0.07750               82              32
#
#      USG%_General  USG%_Clutch
# 5            30.2         40.5
# 162          18.6         22.2
# 364          12.9         15.7
# 253          14.8         25.0
# 359          11.9         16.7
# 77           25.5         28.4
# 41           25.2         35.2
# 55           23.9         30.0
# 56           25.3         34.0
# 34           27.4         33.2
# 13           27.4         30.5
# 31           28.9         35.8
# 360          14.1         14.0
# 207          19.2         21.5
# 2            31.7         32.6
# 213          17.6         17.0
# 237          17.5         21.4
# 58           23.2         26.6
# 20           30.2         35.1
# 67           23.8         27.3
# Top 20 clutch players with filters applied saved to 'Top_20_Clutch_Players_Filtered.xlsx'.

# %%
# Displaying 'Clutch Score' with USG% in regular and clutch time.

# Select only relevant columns for output
top_20_players = df_sorted[['Player', 'Team_General', 'Clutch_Score', 'USG%_General', 'USG%_Clutch']].head(20)

# Display the top 20 players with the highest clutch score
print(top_20_players)

# Save the filtered results to an Excel file
top_20_players.to_excel('Top_20_Clutch_Players_Filtered.xlsx', index=False)

print("Top 20 clutch players saved to 'Top_20_Clutch_Players_Filtered.xlsx'.")
# Out:
#                       Player Team_General  Clutch_Score  USG%_General  \
# 5              Stephen Curry          GSW       0.25685          30.2
# 162              Buddy Hield          PHI       0.18075          18.6
# 364               Josh Green          DAL       0.17480          12.9
# 253               Danté Exum          DAL       0.16775          14.8
# 359              Amir Coffey          LAC       0.16690          11.9
# 77           Jordan Clarkson          UTA       0.15210          25.5
# 41             DeMar DeRozan          CHI       0.14710          25.2
# 55         Tyrese Haliburton          IND       0.14610          23.9
# 56              Terry Rozier          MIA       0.14280          25.3
# 34            Damian Lillard          MIL       0.13600          27.4
# 13              Kyrie Irving          DAL       0.13225          27.4
# 31                Trae Young          ATL       0.11470          28.9
# 360         Patrick Beverley          MIL       0.11350          14.1
# 207           Malaki Branham          SAS       0.10215          19.2
# 2    Shai Gilgeous-Alexander          OKC       0.09925          31.7
# 213            Dillon Brooks          HOU       0.09340          17.6
# 237           Gordon Hayward          OKC       0.09000          17.5
# 58            Jalen Williams          OKC       0.08160          23.2
# 20         Jaren Jackson Jr.          MEM       0.07780          30.2
# 67             Mikal Bridges          BKN       0.07750          23.8
#
#      USG%_Clutch
# 5           40.5
# 162         22.2
# 364         15.7
# 253         25.0
# 359         16.7
# 77          28.4
# 41          35.2
# 55          30.0
# 56          34.0
# 34          33.2
# 13          30.5
# 31          35.8
# 360         14.0
# 207         21.5
# 2           32.6
# 213         17.0
# 237         21.4
# 58          26.6
# 20          35.1
# 67          27.3
# Top 20 clutch players saved to 'Top_20_Clutch_Players_Filtered.xlsx'.

# %%
# Checking for correlation between Clutch Time USG% and Clutch Score

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

# Load the processed Excel file
file_path = 'NBA_Clutch_Performance_Analysis.xlsx'
df = pd.read_excel(file_path, sheet_name='Combined Data')

# Calculate performance scores for general and clutch stats
df['Performance_Score_Clutch'] = (
    1.2 * df['PTS_Clutch'] +
    0.5 * df['FGM_Clutch'] -
    0.25 * df['FGA_Clutch'] -
    0.8 * (df['FTA_Clutch'] - df['FTM_Clutch']) +
    0.5 * df['OREB_Clutch'] +
    0.2 * df['DREB_Clutch'] +
    1.2 * df['STL_Clutch'] +
    1.0 * df['AST_Clutch'] +
    1.0 * df['BLK_Clutch'] -
    0.5 * df['PF_Clutch'] -
    1.0 * df['TOV_Clutch']
)

df['Performance_Score_General'] = (
    1.2 * df['PTS_General'] +
    0.5 * df['FGM_General'] -
    0.25 * df['FGA_General'] -
    0.8 * (df['FTA_General'] - df['FTM_General']) +
    0.5 * df['OREB_General'] +
    0.2 * df['DREB_General'] +
    1.2 * df['STL_General'] +
    1.0 * df['AST_General'] +
    1.0 * df['BLK_General'] -
    0.5 * df['PF_General'] -
    1.0 * df['TOV_General']
)

# Calculate clutch score
df['Clutch_Score'] = df['Performance_Score_Clutch'] - df['Performance_Score_General']

# Apply filtering conditions
filtered_df = df[
    (df['GP_General_Trad'] >= 50) &   # At least 50 games played in general time
    (df['GP_Clutch_Trad'] >= 10) &    # At least 10 games played in clutch time
    (df['USG%_General'] > 10) &       # USG% greater than 10% in general time
    (df['USG%_Clutch'] > 10)          # USG% greater than 10% in clutch time
]

# Calculate correlation statistics
x = filtered_df['USG%_Clutch']
y = filtered_df['Clutch_Score']
slope, intercept, r_value, p_value, std_err = linregress(x, y)
r_squared = r_value ** 2  # R-squared value

# Scatter plot for Clutch Score vs USG% in Clutch Time
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x, y=y, edgecolor='w', s=100, label="Players")

# Add trendline
sns.regplot(x=x, y=y, scatter=False, color='red', label=f"Trendline (R² = {r_squared:.2f})")

# Labeling the plot
plt.title("Correlation between Clutch Score and USG% in Clutch Time")
plt.xlabel("USG% in Clutch Time")
plt.ylabel("Clutch Score")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Checking for Clutch Performance and Clutch USG% correlation for top performers

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

# Load the processed Excel file
file_path = 'NBA_Clutch_Performance_Analysis.xlsx'
df = pd.read_excel(file_path, sheet_name='Combined Data')

# Calculate performance scores for general and clutch stats
df['Performance_Score_Clutch'] = (
    1.2 * df['PTS_Clutch'] +
    0.5 * df['FGM_Clutch'] -
    0.25 * df['FGA_Clutch'] -
    0.8 * (df['FTA_Clutch'] - df['FTM_Clutch']) +
    0.5 * df['OREB_Clutch'] +
    0.2 * df['DREB_Clutch'] +
    1.2 * df['STL_Clutch'] +
    1.0 * df['AST_Clutch'] +
    1.0 * df['BLK_Clutch'] -
    0.5 * df['PF_Clutch'] -
    1.0 * df['TOV_Clutch']
)

df['Performance_Score_General'] = (
    1.2 * df['PTS_General'] +
    0.5 * df['FGM_General'] -
    0.25 * df['FGA_General'] -
    0.8 * (df['FTA_General'] - df['FTM_General']) +
    0.5 * df['OREB_General'] +
    0.2 * df['DREB_General'] +
    1.2 * df['STL_General'] +
    1.0 * df['AST_General'] +
    1.0 * df['BLK_General'] -
    0.5 * df['PF_General'] -
    1.0 * df['TOV_General']
)

# Calculate clutch score
df['Clutch_Score'] = df['Performance_Score_Clutch'] - df['Performance_Score_General']

# Apply filtering conditions
filtered_df = df[
    (df['GP_General_Trad'] >= 50) &   # At least 50 games played in general time
    (df['GP_Clutch_Trad'] >= 10) &    # At least 10 games played in clutch time
    (df['USG%_General'] > 10) &       # USG% greater than 10% in general time
    (df['USG%_Clutch'] > 10)          # USG% greater than 10% in clutch time
]

# Select the top 20 players based on clutch score
top_20_df = filtered_df.nlargest(20, 'Clutch_Score')

# Calculate correlation statistics for top 20
x_top = top_20_df['USG%_Clutch']
y_top = top_20_df['Clutch_Score']
slope, intercept, r_value, p_value, std_err = linregress(x_top, y_top)
r_squared_top = r_value ** 2  # R-squared value

# Scatter plot for Clutch Score vs USG% in Clutch Time for top 20 players
plt.figure(figsize=(12, 8))
sns.scatterplot(x=top_20_df['USG%_Clutch'], y=top_20_df['Clutch_Score'], edgecolor='w', s=150)

# Add player names next to each point
for i, row in top_20_df.iterrows():
    plt.text(row['USG%_Clutch'] + 0.2, row['Clutch_Score'], row['Player'], fontsize=10)

# Add trendline for top 20 players
sns.regplot(x=x_top, y=y_top, scatter=False, color='red', label=f"Trendline (R² = {r_squared_top:.2f})")

# Labeling the plot
plt.title("Top 20 Players: Clutch Score vs USG% in Clutch Time")
plt.xlabel("USG% in Clutch Time")
plt.ylabel("Clutch Score")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
## Review how many players have a positive clutch score

import pandas as pd

# Filter and sort players with positive clutch scores
positive_clutch_players = filtered_df[filtered_df['Clutch_Score'] > 0].sort_values(by='Clutch_Score', ascending=False)
negative_clutch_players = filtered_df[filtered_df['Clutch_Score'] < 0].sort_values(by='Clutch_Score', ascending=False)

# Display the counts
print(f"Number of players with positive clutch score: {len(positive_clutch_players)}")
print(f"Number of players with negative clutch score: {len(negative_clutch_players)}")

# Show the players with positive clutch scores sorted
print("\nPlayers with Positive Clutch Score (Sorted Highest to Lowest):")
print(positive_clutch_players[['Player', 'Team_General', 'Clutch_Score']].to_string(index=False))

# Show the players with negative clutch scores sorted
print("\nPlayers with Negative Clutch Score (Sorted Highest to Lowest):")
print(negative_clutch_players[['Player', 'Team_General', 'Clutch_Score']].to_string(index=False))
# Out:
# Number of players with positive clutch score: 153
# Number of players with negative clutch score: 50
#
# Players with Positive Clutch Score (Sorted Highest to Lowest):
#                   Player Team_General  Clutch_Score
#            Stephen Curry          GSW      0.633375
#        Tyrese Haliburton          IND      0.469225
#  Shai Gilgeous-Alexander          OKC      0.444850
#             Kyrie Irving          DAL      0.443925
#            DeMar DeRozan          CHI      0.436800
#           Damian Lillard          MIL      0.430075
#              Buddy Hield          PHI      0.426925
#             Terry Rozier          MIA      0.422325
#               Trae Young          ATL      0.409450
#          Jordan Clarkson          UTA      0.406975
#               Danté Exum          DAL      0.390750
#               Josh Green          DAL      0.368850
#              Amir Coffey          LAC      0.354075
#             Nikola Jokić          DEN      0.348650
#            Kawhi Leonard          LAC      0.346825
#        Jaren Jackson Jr.          MEM      0.327575
#           Jalen Williams          OKC      0.325575
#             LeBron James          LAL      0.324225
#            Jalen Brunson          NYK      0.319900
#               Malik Monk          SAC      0.305925
#             Jamal Murray          DEN      0.304350
#            Mikal Bridges          BKN      0.298625
#       Kristaps Porziņģis          BOS      0.296100
#         Patrick Beverley          MIL      0.293675
#           Malaki Branham          SAS      0.283475
#           Gordon Hayward          OKC      0.275050
#          Dennis Schröder          BKN      0.274650
#             Tyrese Maxey          PHI      0.270525
#             De'Aaron Fox          SAC      0.264900
#           Alperen Sengun          HOU      0.261850
#            Dillon Brooks          HOU      0.260750
#         Donovan Mitchell          CLE      0.247200
#             Devin Booker          PHX      0.245225
#            Austin Reaves          LAL      0.235875
#          Anthony Edwards          MIN      0.231175
#              Paul George          LAC      0.225675
#           Grant Williams          CHA      0.222500
#           Reggie Jackson          DEN      0.213575
#           Walker Kessler          UTA      0.211150
#            Fred VanVleet          HOU      0.207950
#                 Naz Reid          MIN      0.205750
#             Jayson Tatum          BOS      0.205500
#       Brandin Podziemski          GSW      0.198125
#             Kevin Durant          PHX      0.194925
#           Keyonte George          UTA      0.194825
#            Amen Thompson          HOU      0.193200
#           Scottie Barnes          TOR      0.186975
#         D'Angelo Russell          LAL      0.185425
#          Cade Cunningham          DET      0.184175
#           Andre Drummond          CHI      0.183375
#            Derrick White          BOS      0.182200
#        Spencer Dinwiddie          LAL      0.180650
#               Coby White          CHI      0.179500
#          Lauri Markkanen          UTA      0.178525
#             Bradley Beal          PHX      0.174900
#              Gary Harris          ORL      0.170875
#           Paolo Banchero          ORL      0.168450
#                Josh Hart          NYK      0.167525
#             Kelly Olynyk          TOR      0.167150
#       Karl-Anthony Towns          MIN      0.163775
#        Victor Wembanyama          SAS      0.162450
#    Giannis Antetokounmpo          MIL      0.160325
#        Jonas Valančiūnas          NOP      0.157225
#            Georges Niang          CLE      0.148050
#          Dejounte Murray          ATL      0.144025
#            Peyton Watson          DEN      0.143125
#           Brandon Ingram          NOP      0.137975
#              Ivica Zubac          LAC      0.136750
#            Miles Bridges          CHA      0.135700
#             Jerami Grant          POR      0.135675
#            Chet Holmgren          OKC      0.134475
#            Cason Wallace          OKC      0.134200
#            Royce O'Neale          PHX      0.132825
#        Haywood Highsmith          MIA      0.129175
#               Kyle Kuzma          WAS      0.128150
#              Moses Moody          GSW      0.125575
#             Franz Wagner          ORL      0.122950
#            Anthony Davis          LAL      0.121075
#             Jakob Poeltl          TOR      0.119850
#        Marvin Bagley III          WAS      0.119650
#              Luka Dončić          DAL      0.118800
#             John Collins          UTA      0.115975
#        Derrick Jones Jr.          DAL      0.111175
#           Jonathan Isaac          ORL      0.110850
#         Keita Bates-Diop          BKN      0.109575
#          P.J. Washington          DAL      0.108525
#                Tre Jones          SAS      0.107975
#              Alex Caruso          CHI      0.107900
#         Bojan Bogdanović          NYK      0.107525
#            Norman Powell          LAC      0.106350
#            Herbert Jones          NOP      0.105150
#              Bruce Brown          TOR      0.102300
#              CJ McCollum          NOP      0.100550
#             Aaron Gordon          DEN      0.098150
#         Precious Achiuwa          NYK      0.093550
#         Tim Hardaway Jr.          DAL      0.092075
#           Daniel Gafford          DAL      0.088775
# Nickeil Alexander-Walker          MIN      0.088525
#             Jrue Holiday          BOS      0.087875
#               RJ Barrett          TOR      0.084700
#              Jalen Duren          DET      0.083300
#             Cole Anthony          ORL      0.081700
#          Duncan Robinson          MIA      0.081400
#         Jaime Jaquez Jr.          MIA      0.080550
#             Jusuf Nurkić          PHX      0.075300
#            Deandre Ayton          POR      0.072675
#            Jeremy Sochan          SAS      0.072500
#           Draymond Green          GSW      0.069350
#            Collin Sexton          UTA      0.067650
#            Kevin Huerter          SAC      0.067050
#             Terance Mann          LAC      0.066950
#            Jabari Walker          POR      0.066925
#      Dorian Finney-Smith          BKN      0.065675
#             Jimmy Butler          MIA      0.065475
#             Caris LeVert          CLE      0.063925
#            Tobias Harris          PHI      0.063750
#          Cameron Johnson          BKN      0.062250
#          Pat Connaughton          MIL      0.058550
#         Jabari Smith Jr.          HOU      0.053200
#          Larry Nance Jr.          NOP      0.052525
#               Saddiq Bey          ATL      0.051625
#              Jalen Suggs          ORL      0.051550
#           Darius Garland          CLE      0.050225
#              Jalen Green          HOU      0.048425
#           Gary Trent Jr.          TOR      0.046500
#         Dennis Smith Jr.          BKN      0.045225
#               Kyle Lowry          PHI      0.045125
#            Rui Hachimura          LAL      0.044150
#            Miles McBride          NYK      0.041600
#            Aaron Wiggins          OKC      0.040150
#                Max Strus          CLE      0.040000
#           Nikola Vučević          CHI      0.039875
#        Immanuel Quickley          TOR      0.039475
#              Brook Lopez          MIL      0.033275
#          Scoot Henderson          POR      0.032700
#            Aaron Nesmith          IND      0.029350
#              Josh Giddey          OKC      0.027600
# Kentavious Caldwell-Pope          DEN      0.026125
#             James Harden          LAC      0.021900
#             Jaylen Brown          BOS      0.021600
#         Kenrich Williams          OKC      0.020225
#               Chris Paul          GSW      0.016125
#             Myles Turner          IND      0.015150
#              Ayo Dosunmu          CHI      0.015000
#            Corey Kispert          WAS      0.014950
#           Brandon Miller          CHA      0.014800
#            Jarrett Allen          CLE      0.013150
#            Anthony Black          ORL      0.013025
#       Bennedict Mathurin          IND      0.012225
#        Russell Westbrook          LAC      0.008550
#          Andrew Nembhard          IND      0.008300
#               Jaden Ivey          DET      0.002850
#               Al Horford          BOS      0.002050
#
# Players with Negative Clutch Score (Sorted Highest to Lowest):
#             Player Team_General  Clutch_Score
#      Devin Vassell          SAS     -0.000875
#      Klay Thompson          GSW     -0.002550
#         Cam Thomas          BKN     -0.004350
#       Caleb Martin          MIA     -0.008175
#    Ziaire Williams          MEM     -0.012475
#        Mike Conley          MIN     -0.013075
# Vince Williams Jr.          MEM     -0.013500
#  Bogdan Bogdanović          ATL     -0.013525
#      Pascal Siakam          IND     -0.014050
#       Bobby Portis          MIL     -0.017825
#    Harrison Barnes          SAC     -0.018025
#    Kelly Oubre Jr.          PHI     -0.018650
#         Kevin Love          MIA     -0.018825
#        Evan Mobley          CLE     -0.024775
#    Trey Murphy III          NOP     -0.027575
# Wendell Carter Jr.          ORL     -0.028550
#      Malik Beasley          MIL     -0.033425
#         Alec Burks          NYK     -0.034475
#    Zion Williamson          NOP     -0.038150
#    Khris Middleton          MIL     -0.040025
#         Isaiah Joe          OKC     -0.044925
#     Keldon Johnson          SAS     -0.045725
#     Ausar Thompson          DET     -0.047975
#   Donte DiVincenzo          NYK     -0.050150
#        Bam Adebayo          MIA     -0.050600
#      Keegan Murray          SAC     -0.054975
#        Rudy Gobert          MIN     -0.064825
#   Domantas Sabonis          SAC     -0.067750
#       Zach Collins          SAS     -0.068300
#     T.J. McConnell          IND     -0.073550
#       Santi Aldama          MEM     -0.079700
#      Luguentz Dort          OKC     -0.079800
#     Andrew Wiggins          GSW     -0.080600
#    Jaden McDaniels          MIN     -0.083875
#         Tyus Jones          WAS     -0.101675
#     Jordan Goodwin          MEM     -0.101800
#       Jordan Poole          WAS     -0.106025
#       Clint Capela          ATL     -0.106575
#      Jalen Johnson          ATL     -0.108325
#      Aaron Holiday          HOU     -0.115050
#      Cameron Payne          PHI     -0.119800
#   Jonathan Kuminga          GSW     -0.126350
#    De'Andre Hunter          ATL     -0.126725
#         Obi Toppin          IND     -0.132700
#      Moritz Wagner          ORL     -0.156225
#  Simone Fontecchio          DET     -0.158100
#        Deni Avdija          WAS     -0.161025
#      Naji Marshall          NOP     -0.194400
#        Dario Šarić          GSW     -0.221150
#         Trey Lyles          SAC     -0.231975

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Clutch Score vs General Minutes
plt.figure(figsize=(12, 6))
sns.scatterplot(x=filtered_df['MIN_General'], y=filtered_df['Clutch_Score'], color='blue', edgecolor='w', s=100)
sns.regplot(x=filtered_df['MIN_General'], y=filtered_df['Clutch_Score'], scatter=False, color='blue', line_kws={'linestyle': 'dashed'})

# Title and labels
plt.title("Clutch Score vs General Minutes Played")
plt.xlabel("General Minutes Played")
plt.ylabel("Clutch Score")
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Clutch Score vs Clutch Minutes
plt.figure(figsize=(12, 6))
sns.scatterplot(x=filtered_df['MIN_Clutch'], y=filtered_df['Clutch_Score'], color='red', edgecolor='w', s=100)
sns.regplot(x=filtered_df['MIN_Clutch'], y=filtered_df['Clutch_Score'], scatter=False, color='red', line_kws={'linestyle': 'dashed'})

# Title and labels
plt.title("Clutch Score vs Clutch Minutes Played")
plt.xlabel("Clutch Minutes Played")
plt.ylabel("Clutch Score")
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot for Clutch Score vs Age
plt.figure(figsize=(12, 6))
sns.scatterplot(x=filtered_df['AGE_General'], y=filtered_df['Clutch_Score'], color='green', edgecolor='w', s=100)
sns.regplot(x=filtered_df['AGE_General'], y=filtered_df['Clutch_Score'], scatter=False, color='green', line_kws={'linestyle': 'dashed'})

# Title and labels
plt.title("Clutch Score vs Age")
plt.xlabel("Player Age")
plt.ylabel("Clutch Score")
plt.grid(True)

# Show the plot
plt.show()
